# %% [markdown]
# # Week 2 3/11/2019
# # Class 3

# %% [markdown]
# # Pandas and a lot of Pandas

# %%
import os
import pandas as rohit_pd

# %%
path = 'https://raw.githubusercontent.com/vikrambj2019/basic/master/Data/'
filename_read=os.path.join(path, "auto-mpg.csv")
df=rohit_pd.read_csv(filename_read, na_values=['NA','?'])

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 393  27.0          4         140.0        86.0    2790          15.6    82
# 394  44.0          4          97.0        52.0    2130          24.6    82
# 395  32.0          4         135.0        84.0    2295          11.6    82
# 396  28.0          4         120.0        79.0    2625          18.6    82
# 397  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin             name
# 393       1  ford mustang gl
# 394       2        vw pickup
# 395       1    dodge rampage
# 396       1      ford ranger
# 397       1       chevy s-10

# %%
df[:3]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite

# %%
df[:100]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0   18.0          8         307.0       130.0    3504          12.0    70
# 1   15.0          8         350.0       165.0    3693          11.5    70
# 2   18.0          8         318.0       150.0    3436          11.0    70
# 3   16.0          8         304.0       150.0    3433          12.0    70
# 4   17.0          8         302.0       140.0    3449          10.5    70
# 5   15.0          8         429.0       198.0    4341          10.0    70
# 6   14.0          8         454.0       220.0    4354           9.0    70
# 7   14.0          8         440.0       215.0    4312           8.5    70
# 8   14.0          8         455.0       225.0    4425          10.0    70
# 9   15.0          8         390.0       190.0    3850           8.5    70
# 10  15.0          8         383.0       170.0    3563          10.0    70
# 11  14.0          8         340.0       160.0    3609           8.0    70
# ...

# %%
df[10:14]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 10  15.0          8         383.0       170.0    3563          10.0    70
# 11  14.0          8         340.0       160.0    3609           8.0    70
# 12  15.0          8         400.0       150.0    3761           9.5    70
# 13  14.0          8         455.0       225.0    3086          10.0    70
#
#     origin                     name
# 10       1      dodge challenger se
# 11       1       plymouth 'cuda 340
# 12       1    chevrolet monte carlo
# 13       1  buick estate wagon (sw)

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
df.mean()
# Out:
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# horsepower       104.469388
# weight          2970.424623
# acceleration      15.568090
# year              76.010050
# origin             1.572864
# dtype: float64

# %%
df['mpg'].mean()
# Out:
# 23.514572864321615

# %%
round(df['mpg'].describe(),2)
# Out:
# count    398.00
# mean      23.51
# std        7.82
# min        9.00
# 25%       17.50
# 50%       23.00
# 75%       29.00
# max       46.60
# Name: mpg, dtype: float64

# %%
df['mpg'].describe()
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      392 non-null float64
# weight          398 non-null int64
# acceleration    398 non-null float64
# year            398 non-null int64
# origin          398 non-null int64
# name            398 non-null object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
round(df['horsepower'].describe(),2)
# Out:
# count    392.00
# mean     104.47
# std       38.49
# min       46.00
# 25%       75.00
# 50%       93.50
# 75%      126.00
# max      230.00
# Name: horsepower, dtype: float64

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
columns_need=['mpg','cylinders','displacement']
df[columns_need].mean()
# Out:
# mpg              23.514573
# cylinders         5.454774
# displacement    193.425879
# dtype: float64

# %%
df[columns_need].describe()
# Out:
#               mpg   cylinders  displacement
# count  398.000000  398.000000    398.000000
# mean    23.514573    5.454774    193.425879
# std      7.815984    1.701004    104.269838
# min      9.000000    3.000000     68.000000
# 25%     17.500000    4.000000    104.250000
# 50%     23.000000    4.000000    148.500000
# 75%     29.000000    8.000000    262.000000
# max     46.600000    8.000000    455.000000

# %%
df[columns_need].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 3 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 9.4 KB

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %%
len(df)
# Out:
# 398

# %%
df.values
# Out:
# array([[18.0, 8, 307.0, ..., 70, 1, 'chevrolet chevelle malibu'],
#        [15.0, 8, 350.0, ..., 70, 1, 'buick skylark 320'],
#        [18.0, 8, 318.0, ..., 70, 1, 'plymouth satellite'],
#        ...,
#        [32.0, 4, 135.0, ..., 82, 1, 'dodge rampage'],
#        [28.0, 4, 120.0, ..., 82, 1, 'ford ranger'],
#        [31.0, 4, 119.0, ..., 82, 1, 'chevy s-10']], dtype=object)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-0e566b70f572> in <module>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (398, 9)

# %%
df.size
# Out:
# 3582

# %%
df['wtpercyl']=df['weight']/df['cylinders']

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name  wtpercyl
# 0       1  chevrolet chevelle malibu   438.000
# 1       1          buick skylark 320   461.625
# 2       1         plymouth satellite   429.500
# 3       1              amc rebel sst   429.125
# 4       1                ford torino   431.125

# %%
df['disppercyl']=df['displacement']/df['cylinders']

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name  wtpercyl  disppercyl
# 0       1  chevrolet chevelle malibu   438.000      38.375
# 1       1          buick skylark 320   461.625      43.750
# 2       1         plymouth satellite   429.500      39.750
# 3       1              amc rebel sst   429.125      38.000
# 4       1                ford torino   431.125      37.750

# %%
df['horsepower'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 368    False
# 369    False
# 370    False
# 371    False
# 372    False
# 373    False
# 374     True
# 375    False
# 376    False
# 377    False
# 378    False
# 379    False
# 380    False
# 381    False
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: horsepower, Length: 398, dtype: bool

# %%
df['horsepower']
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
# 5      198.0
# 6      220.0
# 7      215.0
# 8      225.0
# 9      190.0
# 10     170.0
# 11     160.0
# 12     150.0
# 13     225.0
# 14      95.0
# 15      95.0
# 16      97.0
# 17      85.0
# 18      88.0
# 19      46.0
# 20      87.0
# 21      90.0
# 22      95.0
# 23     113.0
# 24      90.0
# 25     215.0
# 26     200.0
# 27     210.0
# 28     193.0
# 29      88.0
#        ...
# 368     88.0
# 369     88.0
# 370     85.0
# 371     84.0
# 372     90.0
# 373     92.0
# 374      NaN
# 375     74.0
# 376     68.0
# 377     68.0
# 378     63.0
# 379     70.0
# 380     88.0
# 381     75.0
# 382     70.0
# 383     67.0
# 384     67.0
# 385     67.0
# 386    110.0
# 387     85.0
# 388     92.0
# 389    112.0
# 390     96.0
# 391     84.0
# 392     90.0
# 393     86.0
# 394     52.0
# 395     84.0
# 396     79.0
# 397     82.0
# Name: horsepower, Length: 398, dtype: float64

# %%
df['horsepower'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 368    False
# 369    False
# 370    False
# 371    False
# 372    False
# 373    False
# 374     True
# 375    False
# 376    False
# 377    False
# 378    False
# 379    False
# 380    False
# 381    False
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: horsepower, Length: 398, dtype: bool

# %%
df[df['horsepower'].isnull()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 32 to 374
# Data columns (total 11 columns):
# mpg             6 non-null float64
# cylinders       6 non-null int64
# displacement    6 non-null float64
# horsepower      0 non-null float64
# weight          6 non-null int64
# acceleration    6 non-null float64
# year            6 non-null int64
# origin          6 non-null int64
# name            6 non-null object
# wtpercyl        6 non-null float64
# disppercyl      6 non-null float64
# dtypes: float64(6), int64(4), object(1)
# memory usage: 576.0+ bytes

# %%
df[df['horsepower'].isnull()].describe()
# Out:
#              mpg  cylinders  displacement  horsepower       weight  \
# count   6.000000   6.000000       6.00000         0.0     6.000000
# mean   28.000000   4.333333     129.00000         NaN  2502.666667
# std     7.886951   0.816497      43.32205         NaN   504.296209
# min    21.000000   4.000000      85.00000         NaN  1835.000000
# 25%    23.150000   4.000000      98.50000         NaN  2114.500000
# 50%    24.300000   4.000000     120.00000         NaN  2597.500000
# 75%    32.125000   4.000000     148.25000         NaN  2897.500000
# max    40.900000   6.000000     200.00000         NaN  3035.000000
#
#        acceleration       year    origin    wtpercyl  disppercyl
# count      6.000000   6.000000  6.000000    6.000000    6.000000
# mean      17.316667  78.000000  1.333333  585.736111   29.472222
# std        2.212163   4.427189  0.516398  128.611338    6.727775
# min       14.300000  71.000000  1.000000  458.750000   21.250000
# ...

# %%
df[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-78a33f69c558> in <module>()
# ----> 1 df[1]
#
# ...

# %%
df['horsepower'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 368    False
# 369    False
# 370    False
# 371    False
# 372    False
# 373    False
# 374     True
# 375    False
# 376    False
# 377    False
# 378    False
# 379    False
# 380    False
# 381    False
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: horsepower, Length: 398, dtype: bool

# %%
df[df['horsepower'].isnull()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 32   25.0          4          98.0         NaN    2046          19.0    71
# 126  21.0          6         200.0         NaN    2875          17.0    74
# 330  40.9          4          85.0         NaN    1835          17.3    80
# 336  23.6          4         140.0         NaN    2905          14.3    80
# 354  34.5          4         100.0         NaN    2320          15.8    81
# 374  23.0          4         151.0         NaN    3035          20.5    82
#
#      origin                  name    wtpercyl  disppercyl
# 32        1            ford pinto  511.500000   24.500000
# 126       1         ford maverick  479.166667   33.333333
# 330       2  renault lecar deluxe  458.750000   21.250000
# 336       1    ford mustang cobra  726.250000   35.000000
# 354       2           renault 18i  580.000000   25.000000
# 374       1        amc concord dl  758.750000   37.750000

# %%
df[True]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-570d3e379dbf> in <module>()
# ----> 1 df[True]
#
# ...

# %%
df['True']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'True'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-7b1935357624> in <module>()
# ----> 1 df['True']
#
# ...

# %%
df['horsepower'].notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 368     True
# 369     True
# 370     True
# 371     True
# 372     True
# 373     True
# 374    False
# 375     True
# 376     True
# 377     True
# 378     True
# 379     True
# 380     True
# 381     True
# 382     True
# 383     True
# 384     True
# 385     True
# 386     True
# 387     True
# 388     True
# 389     True
# 390     True
# 391     True
# 392     True
# 393     True
# 394     True
# 395     True
# 396     True
# 397     True
# Name: horsepower, Length: 398, dtype: bool

# %%
df[df['horsepower'].notnull()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# 5    15.0          8         429.0       198.0    4341          10.0    70
# 6    14.0          8         454.0       220.0    4354           9.0    70
# 7    14.0          8         440.0       215.0    4312           8.5    70
# 8    14.0          8         455.0       225.0    4425          10.0    70
# 9    15.0          8         390.0       190.0    3850           8.5    70
# 10   15.0          8         383.0       170.0    3563          10.0    70
# ...

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name', 'wtpercyl', 'disppercyl'],
#       dtype='object')

# %%
for i in df.columns:
    print(i)
# Out:
# mpg
# cylinders
# displacement
# horsepower
# weight
# acceleration
# year
# origin
# name
# wtpercyl
# disppercyl

# %%
for i in df.columns:
    print(i)
    print(df[df[i].isnull()])
# Out:
# mpg
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name, wtpercyl, disppercyl]
# Index: []
# cylinders
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name, wtpercyl, disppercyl]
# Index: []
# displacement
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name, wtpercyl, disppercyl]
# Index: []
# horsepower
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 32   25.0          4          98.0         NaN    2046          19.0    71
# 126  21.0          6         200.0         NaN    2875          17.0    74
# 330  40.9          4          85.0         NaN    1835          17.3    80
# 336  23.6          4         140.0         NaN    2905          14.3    80
# 354  34.5          4         100.0         NaN    2320          15.8    81
# ...

# %%
for i in df.columns:
    print(i)
    print(df[i].isnull())
# Out:
# mpg
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 368    False
# 369    False
# 370    False
# 371    False
# 372    False
# 373    False
# 374    False
# 375    False
# 376    False
# 377    False
# 378    False
# 379    False
# 380    False
# 381    False
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: mpg, Length: 398, dtype: bool
# cylinders
# 0      False
# 1      False
# ...

# %%
import random

# %%
df['rand_val']=random.randint(1,3)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name  wtpercyl  disppercyl  rand_val
# 0       1  chevrolet chevelle malibu   438.000      38.375         2
# 1       1          buick skylark 320   461.625      43.750         2
# 2       1         plymouth satellite   429.500      39.750         2
# 3       1              amc rebel sst   429.125      38.000         2
# 4       1                ford torino   431.125      37.750         2

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# 5    15.0          8         429.0       198.0    4341          10.0    70
# 6    14.0          8         454.0       220.0    4354           9.0    70
# 7    14.0          8         440.0       215.0    4312           8.5    70
# 8    14.0          8         455.0       225.0    4425          10.0    70
# 9    15.0          8         390.0       190.0    3850           8.5    70
# 10   15.0          8         383.0       170.0    3563          10.0    70
# ...

# %%
len(df)
# Out:
# 398

# %%
df.iloc[100,5]
# Out:
# 16.5

# %%
df.iloc[0,3]
# Out:
# 130.0

# %%
df.iloc[0,0]
# Out:
# 18.0

# %%
df.iloc[0,4]
# Out:
# 3504

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name', 'wtpercyl', 'disppercyl',
#        'rand_val'],
#       dtype='object')

# %%
df.iloc[0,12]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-c6a9cf146f2e> in <module>()
# ----> 1 df.iloc[0,12]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2011     def _getitem_tuple(self, tup):
#    2012
# -> 2013         self._has_valid_tuple(tup)
#    2014         try:
#    2015             return self._getitem_lowerdim(tup)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     220                 raise IndexingError('Too many indexers')
#     221             try:
# ...

# %%
df.iloc[0,11]
# Out:
# 2

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# 5    15.0          8         429.0       198.0    4341          10.0    70
# 6    14.0          8         454.0       220.0    4354           9.0    70
# 7    14.0          8         440.0       215.0    4312           8.5    70
# 8    14.0          8         455.0       225.0    4425          10.0    70
# 9    15.0          8         390.0       190.0    3850           8.5    70
# 10   15.0          8         383.0       170.0    3563          10.0    70
# ...

# %%
for i in range(0,len(df)-1):
    df.iloc[i,12]=random.randint(1,3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-8c3c3e4022f3> in <module>()
#       1 for i in range(0,len(df)-1):
# ----> 2     df.iloc[i,12]=random.randint(1,3)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     186         else:
#     187             key = com._apply_if_callable(key, self.obj)
# --> 188         indexer = self._get_setitem_indexer(key)
#     189         self._setitem_with_indexer(indexer, value)
#     190
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     164         if isinstance(key, tuple):
#     165             try:
# --> 166                 return self._convert_tuple(key, is_setter=True)
#     167             except IndexingError:
#     168                 pass
#
# ...

# %%
for i in range(1,len(df)):
    df.iloc[i,12]=random.randint(1,3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-f3e5c93337fd> in <module>()
#       1 for i in range(1,len(df)):
# ----> 2     df.iloc[i,12]=random.randint(1,3)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     186         else:
#     187             key = com._apply_if_callable(key, self.obj)
# --> 188         indexer = self._get_setitem_indexer(key)
#     189         self._setitem_with_indexer(indexer, value)
#     190
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     164         if isinstance(key, tuple):
#     165             try:
# --> 166                 return self._convert_tuple(key, is_setter=True)
#     167             except IndexingError:
#     168                 pass
#
# ...

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name  wtpercyl  disppercyl  rand_val
# 0       1  chevrolet chevelle malibu   438.000      38.375         2
# 1       1          buick skylark 320   461.625      43.750         2
# 2       1         plymouth satellite   429.500      39.750         2
# 3       1              amc rebel sst   429.125      38.000         2
# 4       1                ford torino   431.125      37.750         2

# %%
for i in range(0,len(df)-1):
    df.iloc[i,11]=random.randint(1,3)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name  wtpercyl  disppercyl  rand_val
# 0       1  chevrolet chevelle malibu   438.000      38.375         1
# 1       1          buick skylark 320   461.625      43.750         3
# 2       1         plymouth satellite   429.500      39.750         1
# 3       1              amc rebel sst   429.125      38.000         1
# 4       1                ford torino   431.125      37.750         3

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# 5    15.0          8         429.0       198.0    4341          10.0    70
# 6    14.0          8         454.0       220.0    4354           9.0    70
# 7    14.0          8         440.0       215.0    4312           8.5    70
# 8    14.0          8         455.0       225.0    4425          10.0    70
# 9    15.0          8         390.0       190.0    3850           8.5    70
# 10   15.0          8         383.0       170.0    3563          10.0    70
# ...

# %%
df['rand_val'].unique()
# Out:
# 1    138
# 2    132
# 3    128
# Name: rand_val, dtype: int64

# %%
df['rand_val'].unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %%
df['mpg'].unique()
# Out:
# array([18. , 15. , 16. , 17. , 14. , 24. , 22. , 21. , 27. , 26. , 25. ,
#        10. , 11. ,  9. , 28. , 19. , 12. , 13. , 23. , 30. , 31. , 35. ,
#        20. , 29. , 32. , 33. , 17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5,
#        26.5, 16.5, 31.5, 36. , 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1,
#        32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1,
#        17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2,
#        19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2,
#        34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4,
#        24.3, 19.1, 34.3, 29.8, 31.3, 37. , 32.2, 46.6, 27.9, 40.8, 44.3,
#        43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6, 25.8,
#        23.5, 39.1, 39. , 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9,
#        31.6, 28.1, 30.7, 24.2, 22.4, 34. , 38. , 44. ])

# %%
df['mpg'].value_counts()
# Out:
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
# 16.0    13
# 19.0    12
# 24.0    11
# 25.0    11
# 28.0    10
# 22.0    10
# 23.0    10
# 20.0     9
# 27.0     9
# 29.0     8
# 21.0     8
# 30.0     7
# 31.0     7
# 17.0     7
# 12.0     6
# 36.0     6
# 32.0     6
# 17.5     5
# 15.5     5
# 11.0     4
# 38.0     4
# 20.2     4
# 21.5     3
# 33.0     3
# 18.5     3
#         ..
# 20.8     1
# 23.6     1
# 30.9     1
# 43.4     1
# 39.1     1
# 40.9     1
# 20.3     1
# 34.7     1
# 32.9     1
# 22.3     1
# 46.6     1
# 32.2     1
# 26.8     1
# 19.1     1
# 27.5     1
# 19.9     1
# 41.5     1
# 31.6     1
# 35.7     1
# 23.5     1
# 39.0     1
# 25.1     1
# 32.8     1
# 44.0     1
# 28.8     1
# 34.2     1
# 38.1     1
# 37.2     1
# 32.1     1
# 32.7     1
# Name: mpg, Length: 129, dtype: int64

# %%
import numpy as np

# %%
df.pivot_table(index=['cylinders','origin'],values=['mpg'],aggfunc=np.mean)
# Out:
#                         mpg
# cylinders origin
# 3         3       20.550000
# 4         1       27.840278
#           2       28.411111
#           3       31.595652
# 5         2       27.366667
# 6         1       19.663514
#           2       20.100000
#           3       23.883333
# 8         1       14.963107

# %%
df.pivot_table(index=['cylinders'],values=['mpg'],aggfunc=np.mean)
# Out:
#                  mpg
# cylinders
# 3          20.550000
# 4          29.286765
# 5          27.366667
# 6          19.985714
# 8          14.963107

# %%
df.pivot_table(index=['origin'],values=['mpg'],aggfunc=np.mean)
# Out:
#               mpg
# origin
# 1       20.083534
# 2       27.891429
# 3       30.450633

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name  wtpercyl  disppercyl  rand_val
# 0       1  chevrolet chevelle malibu   438.000      38.375         1
# 1       1          buick skylark 320   461.625      43.750         3
# 2       1         plymouth satellite   429.500      39.750         1
# 3       1              amc rebel sst   429.125      38.000         1
# 4       1                ford torino   431.125      37.750         3

# %%
df.pivot_table(index=['cylinders', 'year'],values=['mpg'],aggfunc=np.mean)
# Out:
#                       mpg
# cylinders year
# 3         72    19.000000
#           73    18.000000
#           77    21.500000
#           80    23.700000
# 4         70    25.285714
#           71    27.461538
#           72    23.428571
#           73    22.727273
#           74    27.800000
#           75    25.250000
#           76    26.766667
#           77    29.107143
#           78    29.576471
#           79    31.525000
#           80    34.612000
#           81    32.814286
#           82    32.071429
# 5         78    20.300000
#           79    25.400000
#           80    36.400000
# 6         70    20.500000
#           71    18.000000
#           73    19.000000
#           74    17.857143
#           75    17.583333
#           76    20.000000
#           77    19.500000
#           78    19.066667
#           79    22.950000
#           80    25.900000
#           81    23.428571
#           82    28.333333
# 8         70    14.111111
#           71    13.428571
# ...

# %%
df.pivot_table(index=['year','cylinders'],values=['mpg'],aggfunc=np.mean)
# Out:
#                       mpg
# year cylinders
# 70   4          25.285714
#      6          20.500000
#      8          14.111111
# 71   4          27.461538
#      6          18.000000
#      8          13.428571
# 72   3          19.000000
#      4          23.428571
#      8          13.615385
# 73   3          18.000000
#      4          22.727273
#      6          19.000000
#      8          13.200000
# 74   4          27.800000
#      6          17.857143
#      8          14.200000
# 75   4          25.250000
#      6          17.583333
#      8          15.666667
# 76   4          26.766667
#      6          20.000000
#      8          14.666667
# 77   3          21.500000
#      4          29.107143
#      6          19.500000
#      8          16.000000
# 78   4          29.576471
#      5          20.300000
#      6          19.066667
#      8          19.050000
# 79   4          31.525000
#      5          25.400000
#      6          22.950000
#      8          18.630000
# ...

# %%
df.pivot_table(index=['year','cylinders'],values=['mpg'],aggfunc=np.mean, min, max)
# Out:
#   File "<ipython-input-78-4c7e2259fc1f>", line 1
#     df.pivot_table(index=['year','cylinders'],values=['mpg'],aggfunc=np.mean, min, max)
#                                                                              ^
# SyntaxError: positional argument follows keyword argument

# %%
df.pivot_table(index=['year','cylinders'],values=['mpg'],aggfunc=np.mean,np.std)
# Out:
#   File "<ipython-input-79-1e7416b7f7bf>", line 1
#     df.pivot_table(index=['year','cylinders'],values=['mpg'],aggfunc=np.mean,np.std)
#                                                                             ^
# SyntaxError: positional argument follows keyword argument

# %%
df.pivot_table(index=['year','cylinders'],values=['mpg'],aggfunc=np.std)
# Out:
#                      mpg
# year cylinders
# 70   4          1.112697
#      6          1.732051
#      8          2.609685
# 71   4          3.502746
#      6          1.069045
#      8          0.786796
# 72   4          3.056249
#      8          1.502135
# 73   4          3.319365
#      6          2.203893
#      8          1.361114
# 74   4          2.932576
#      6          2.267787
#      8          1.095445
# 75   4          3.333712
#      6          2.020726
#      8          2.422120
# 76   4          3.825976
#      6          2.494438
#      8          1.767767
# 77   4          4.039129
#      6          1.767767
#      8          0.845154
# 78   4          6.384799
#      6          1.548802
#      8          1.048332
# 79   4          4.349739
#      6          3.851104
#      8          2.757636
# 80   4          6.597621
#      6          9.616652
# 81   4          3.844904
#      6          4.139531
# 82   4          5.054727
#      6          8.504901

# %%
df_1=df[df['rand_val']==1]
df_2=df[df['rand_val']==2]
df_3=df[df['rand_val']==3]

# %%
df_1
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 5    15.0          8         429.0       198.0    4341          10.0    70
# 9    15.0          8         390.0       190.0    3850           8.5    70
# 11   14.0          8         340.0       160.0    3609           8.0    70
# 18   27.0          4          97.0        88.0    2130          14.5    70
# 21   24.0          4         107.0        90.0    2430          14.5    70
# 23   26.0          4         121.0       113.0    2234          12.5    70
# 27   11.0          8         318.0       210.0    4382          13.5    70
# 28    9.0          8         304.0       193.0    4732          18.5    70
# ...

# %%
df_4=df[(df['rand_val']==1) & (df['rand_val']==2)]

# %%
df_4
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name, wtpercyl, disppercyl, rand_val]
# Index: []

# %%
print(len(df_1))
# Out:
# 138

# %%
len(df_1)
# Out:
# 138

# %%
df_4=df[(df['rand_val']==1) | (df['rand_val']==2)]

# %%
df_4
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 5    15.0          8         429.0       198.0    4341          10.0    70
# 6    14.0          8         454.0       220.0    4354           9.0    70
# 9    15.0          8         390.0       190.0    3850           8.5    70
# 11   14.0          8         340.0       160.0    3609           8.0    70
# 16   18.0          6         199.0        97.0    2774          15.5    70
# 17   21.0          6         200.0        85.0    2587          16.0    70
# 18   27.0          4          97.0        88.0    2130          14.5    70
# 20   25.0          4         110.0        87.0    2672          17.5    70
# ...

# %%
len(df_4)
# Out:
# 270

# %%
print(len(df_2))
# Out:
# 132

# %%
print(len(df_3))
# Out:
# 128

# %%
print(len(df_4))
# Out:
# 270

# %%
df_1=df_1.append(df_2)

# %%
len(df_l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-23467207f479> in <module>()
# ----> 1 len(df_l)
#
# NameError: name 'df_l' is not defined

# %%
len(df_1)
# Out:
# 270

# %%
df_1=df_1.append(df_3)

# %%
len(df_1)
# Out:
# 398

# %% [markdown]
# # HW

# %%
import os
import pandas as rohit_pd

# %%
path = 'https://raw.githubusercontent.com/vikrambj2019/basic/master/Data/'
filename_read=os.path.join(path, "boston-house-prices.csv")
df=rohit_pd.read_csv(filename_read, na_values=['NA','?'])

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
df[:3]
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7

# %%
df[:100]
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11  0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df[10:14]
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 10  0.22489  12.5   7.87     0  0.524  6.377  94.3  6.3467    5  311     15.2
# 11  0.11747  12.5   7.87     0  0.524  6.009  82.9  6.2267    5  311     15.2
# 12  0.09378  12.5   7.87     0  0.524  5.889  39.0  5.4509    5  311     15.2
# 13  0.62976   0.0   8.14     0  0.538  5.949  61.8  4.7075    4  307     21.0
#
#          B  LSTAT  MEDV
# 10  392.52  20.45  15.0
# 11  396.90  13.27  18.9
# 12  390.50  15.71  21.7
# 13  396.90   8.26  20.4

# %%
df.mean()
# Out:
# CRIM         3.613524
# ZN          11.363636
# INDUS       11.136779
# CHAS         0.069170
# NOX          0.554695
# RM           6.284634
# AGE         68.574901
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.653063
# MEDV        22.532806
# dtype: float64

# %%
df['CRIM'].mean()
# Out:
# 3.6135235573122535

# %%
round(df['CRIM'].describe(),2)
# Out:
# count    506.00
# mean       3.61
# std        8.60
# min        0.01
# 25%        0.08
# 50%        0.26
# 75%        3.68
# max       88.98
# Name: CRIM, dtype: float64

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
columns_need=['CRIM','ZN','INDUS']
df[columns_need].mean()
# Out:
# CRIM      3.613524
# ZN       11.363636
# INDUS    11.136779
# dtype: float64

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
len(df)
# Out:
# 506

# %%
df.shape
# Out:
# (506, 14)

# %%
df.size
# Out:
# 7084

# %%
for i in df.columns:
    print(i)
# Out:
# CRIM
# ZN
# INDUS
# CHAS
# NOX
# RM
# AGE
# DIS
# RAD
# TAX
# PTRATIO
# B
# LSTAT
# MEDV

# %%
for i in df.columns:
    print(i)
    print(df[df[i].isnull()])
# Out:
# CRIM
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []
# ZN
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []
# INDUS
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []
# CHAS
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []
# NOX
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []
# RM
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []
# AGE
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []
# DIS
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# ...

# %%
import random

# %%
df['rand_val']=random.randint(1,10)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV  rand_val
# 0  396.90   4.98  24.0         8
# 1  396.90   9.14  21.6         8
# 2  392.83   4.03  34.7         8
# 3  394.63   2.94  33.4         8
# 4  396.90   5.33  36.2         8

# %%
df.iloc[0,0]
# Out:
# 0.00632

# %%
df
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6     0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10    0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
for i in range(0,5):
    df.iloc[i,2]

# %%
df.iloc[0,2]
# Out:
# 2.31

# %%
for i in range(0,5):
    print(df.iloc[i,2])
# Out:
# 2.31
# 7.07
# 7.07
# 2.18
# 2.18

# %%
for i in range(0,len(df)-1):
    df.iloc[i,14]=random.randint(1,10)

# %%
df
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6     0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10    0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
df['rand_val'].value_counts()
# Out:
# 6     62
# 9     54
# 8     53
# 2     53
# 5     52
# 1     51
# 7     46
# 4     46
# 10    45
# 3     44
# Name: rand_val, dtype: int64

# %%
df['rand_val'].unique()
# Out:
# array([10,  5,  6,  8,  9,  2,  4,  1,  3,  7], dtype=int64)

# %%
 import numpy as np

# %%
df_1=df[(df['rand_val']<8)]
df_2=df[(df['rand_val'] > 7) & (df['rand_val'] < 10)]
df_3=df[df['rand_val']==10]

# %%
len(df_1)
# Out:
# 354

# %%
len(df_2)
# Out:
# 107

# %%
len(df_3)
# Out:
# 45

# %%
df_2
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 11    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# 18    0.80271   0.0   8.14     0  0.538  5.456   36.6  3.7965    4  307
# 24    0.75026   0.0   8.14     0  0.538  5.924   94.1  4.3996    4  307
# 25    0.84054   0.0   8.14     0  0.538  5.599   85.7  4.4546    4  307
# 38    0.17505   0.0   5.96     0  0.499  5.966   30.2  3.8473    5  279
# 39    0.02763  75.0   2.95     0  0.428  6.595   21.8  5.4011    3  252
# 46    0.18836   0.0   6.91     0  0.448  5.786   33.3  5.1004    3  233
# 47    0.22927   0.0   6.91     0  0.448  6.030   85.5  5.6894    3  233
# 50    0.08873  21.0   5.64     0  0.439  5.963   45.7  6.8147    4  243
# 55    0.01311  90.0   1.22     0  0.403  7.249   21.9  8.6966    5  226
# ...

# %%
df['rand_val'].unique()
# Out:
# array([10,  5,  6,  8,  9,  2,  4,  1,  3,  7], dtype=int64)

# %%
df['rand_val'].value_counts()
# Out:
# 6     62
# 9     54
# 8     53
# 2     53
# 5     52
# 1     51
# 7     46
# 4     46
# 10    45
# 3     44
# Name: rand_val, dtype: int64

# %%
df_3
# Out:
#          CRIM     ZN  INDUS  CHAS    NOX     RM    AGE      DIS  RAD  TAX  \
# 0     0.00632   18.0   2.31     0  0.538  6.575   65.2   4.0900    1  296
# 6     0.08829   12.5   7.87     0  0.524  6.012   66.6   5.5605    5  311
# 13    0.62976    0.0   8.14     0  0.538  5.949   61.8   4.7075    4  307
# 48    0.25387    0.0   6.91     0  0.448  5.399   95.3   5.8700    3  233
# 57    0.01432  100.0   1.32     0  0.411  6.816   40.5   8.3248    5  256
# 67    0.05789   12.5   6.07     0  0.409  5.878   21.4   6.4980    4  345
# 77    0.08707    0.0  12.83     0  0.437  6.140   45.8   4.0905    5  398
# 88    0.05660    0.0   3.41     0  0.489  7.007   86.3   3.4217    2  270
# 91    0.03932    0.0   3.41     0  0.489  6.405   73.9   3.0921    2  270
# 100   0.14866    0.0   8.56     0  0.520  6.727   79.9   2.7778    5  384
# 103   0.21161    0.0   8.56     0  0.520  6.137   87.4   2.7147    5  384
# 104   0.13960    0.0   8.56     0  0.520  6.167   90.0   2.4210    5  384
# ...

# %%
df_1
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10    0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 12    0.09378  12.5   7.87     0  0.524  5.889   39.0  5.4509    5  311
# 14    0.63796   0.0   8.14     0  0.538  6.096   84.5  4.4619    4  307
# 15    0.62739   0.0   8.14     0  0.538  5.834   56.5  4.4986    4  307
# 16    1.05393   0.0   8.14     0  0.538  5.935   29.3  4.4986    4  307
# 17    0.78420   0.0   8.14     0  0.538  5.990   81.7  4.2579    4  307
# ...

# %% [markdown]
# # Class 4

# %% [markdown]
# ** More Functions on pandas and start plotting

# %%
import os
import numpy as np
import pandas as pd

# %%
path ='https://raw.githubusercontent.com/vikrambj2019/basic/master/Data/'
filename_read=os.path.join(path,"auto-mpg.csv")
df=pd.read_csv(filename_read,na_values=['NA','?'])

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
df[df['horsepower'].isnull()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 32   25.0          4          98.0         NaN    2046          19.0    71
# 126  21.0          6         200.0         NaN    2875          17.0    74
# 330  40.9          4          85.0         NaN    1835          17.3    80
# 336  23.6          4         140.0         NaN    2905          14.3    80
# 354  34.5          4         100.0         NaN    2320          15.8    81
# 374  23.0          4         151.0         NaN    3035          20.5    82
#
#      origin                  name
# 32        1            ford pinto
# 126       1         ford maverick
# 330       2  renault lecar deluxe
# 336       1    ford mustang cobra
# 354       2           renault 18i
# 374       1        amc concord dl

# %%
# This loop will iterate through all columns
for i in df.columns:
    #print(i)
    print(df[df[i].isnull()])
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name]
# Index: []
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name]
# Index: []
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name]
# Index: []
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 32   25.0          4          98.0         NaN    2046          19.0    71
# 126  21.0          6         200.0         NaN    2875          17.0    74
# 330  40.9          4          85.0         NaN    1835          17.3    80
# 336  23.6          4         140.0         NaN    2905          14.3    80
# 354  34.5          4         100.0         NaN    2320          15.8    81
# 374  23.0          4         151.0         NaN    3035          20.5    82
#
#      origin                  name
# 32        1            ford pinto
# ...

# %%
df.pivot_table(index=['cylinders'],values=['horsepower'],aggfunc=np.mean)
# Out:
#            horsepower
# cylinders
# 3           99.250000
# 4           78.281407
# 5           82.333333
# 6          101.506024
# 8          158.300971

# %%
df.groupby(['cylinders'])['horsepower'].transform('mean')
# Out:
# 0      158.300971
# 1      158.300971
# 2      158.300971
# 3      158.300971
# 4      158.300971
# 5      158.300971
# 6      158.300971
# 7      158.300971
# 8      158.300971
# 9      158.300971
# 10     158.300971
# 11     158.300971
# 12     158.300971
# 13     158.300971
# 14      78.281407
# 15     101.506024
# 16     101.506024
# 17     101.506024
# 18      78.281407
# 19      78.281407
# 20      78.281407
# 21      78.281407
# 22      78.281407
# 23      78.281407
# 24     101.506024
# 25     158.300971
# 26     158.300971
# 27     158.300971
# 28     158.300971
# 29      78.281407
#           ...
# 368     78.281407
# 369     78.281407
# 370     78.281407
# 371     78.281407
# 372     78.281407
# 373     78.281407
# 374     78.281407
# 375     78.281407
# 376     78.281407
# 377     78.281407
# 378     78.281407
# 379     78.281407
# 380     78.281407
# 381     78.281407
# 382     78.281407
# 383     78.281407
# 384     78.281407
# 385     78.281407
# 386    101.506024
# ...

# %%
df.groupby(['cylinders'])['horsepower']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ad021e83df54> in <module>()
# ----> 1 df.groupby(['cylinders'])['horsepower']
#
# NameError: name 'df' is not defined

# %%
df.groupby(['cylinders'])['horsepower'])
# Out:
#   File "<ipython-input-2-632ed29239f1>", line 1
#     df.groupby(['cylinders'])['horsepower'])
#                                            ^
# SyntaxError: invalid syntax

# %%
df.groupby(['cylinders'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-76569ed244cc> in <module>()
# ----> 1 df.groupby(['cylinders'])
#
# NameError: name 'df' is not defined

# %%
df.groupby(['cylinders'])['horsepower'].transform('mean')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e0d11fa3eefc> in <module>()
# ----> 1 df.groupby(['cylinders'])['horsepower'].transform('mean')
#
# NameError: name 'df' is not defined

# %%
import os
import numpy as np
import pandas as pd

# %%
path ='https://raw.githubusercontent.com/vikrambj2019/basic/master/Data/'
filename_read=os.path.join(path,"auto-mpg.csv")
df=pd.read_csv(filename_read,na_values=['NA','?'])

# %%
df.groupby(['cylinders'])

# %%
df.groupby(['cylinders'])['horsepower'].transform('mean')
# Out:
# 0      158.300971
# 1      158.300971
# 2      158.300971
# 3      158.300971
# 4      158.300971
# 5      158.300971
# 6      158.300971
# 7      158.300971
# 8      158.300971
# 9      158.300971
# 10     158.300971
# 11     158.300971
# 12     158.300971
# 13     158.300971
# 14      78.281407
# 15     101.506024
# 16     101.506024
# 17     101.506024
# 18      78.281407
# 19      78.281407
# 20      78.281407
# 21      78.281407
# 22      78.281407
# 23      78.281407
# 24     101.506024
# 25     158.300971
# 26     158.300971
# 27     158.300971
# 28     158.300971
# 29      78.281407
#           ...
# 368     78.281407
# 369     78.281407
# 370     78.281407
# 371     78.281407
# 372     78.281407
# 373     78.281407
# 374     78.281407
# 375     78.281407
# 376     78.281407
# 377     78.281407
# 378     78.281407
# 379     78.281407
# 380     78.281407
# 381     78.281407
# 382     78.281407
# 383     78.281407
# 384     78.281407
# 385     78.281407
# 386    101.506024
# ...

# %%
df.groupby(['cylinders'])['horsepower']

# %%
df.groupby(['cylinders'])['horsepower'].transform('mean')
# Out:
# 0      158.300971
# 1      158.300971
# 2      158.300971
# 3      158.300971
# 4      158.300971
# 5      158.300971
# 6      158.300971
# 7      158.300971
# 8      158.300971
# 9      158.300971
# 10     158.300971
# 11     158.300971
# 12     158.300971
# 13     158.300971
# 14      78.281407
# 15     101.506024
# 16     101.506024
# 17     101.506024
# 18      78.281407
# 19      78.281407
# 20      78.281407
# 21      78.281407
# 22      78.281407
# 23      78.281407
# 24     101.506024
# 25     158.300971
# 26     158.300971
# 27     158.300971
# 28     158.300971
# 29      78.281407
#           ...
# 368     78.281407
# 369     78.281407
# 370     78.281407
# 371     78.281407
# 372     78.281407
# 373     78.281407
# 374     78.281407
# 375     78.281407
# 376     78.281407
# 377     78.281407
# 378     78.281407
# 379     78.281407
# 380     78.281407
# 381     78.281407
# 382     78.281407
# 383     78.281407
# 384     78.281407
# 385     78.281407
# 386    101.506024
# ...

# %%
df.groupby(['cylinders'])['horsepower'].transform('sum')
# Out:
# 0      16305.0
# 1      16305.0
# 2      16305.0
# 3      16305.0
# 4      16305.0
# 5      16305.0
# 6      16305.0
# 7      16305.0
# 8      16305.0
# 9      16305.0
# 10     16305.0
# 11     16305.0
# 12     16305.0
# 13     16305.0
# 14     15578.0
# 15      8425.0
# 16      8425.0
# 17      8425.0
# 18     15578.0
# 19     15578.0
# 20     15578.0
# 21     15578.0
# 22     15578.0
# 23     15578.0
# 24      8425.0
# 25     16305.0
# 26     16305.0
# 27     16305.0
# 28     16305.0
# 29     15578.0
#         ...
# 368    15578.0
# 369    15578.0
# 370    15578.0
# 371    15578.0
# 372    15578.0
# 373    15578.0
# 374    15578.0
# 375    15578.0
# 376    15578.0
# 377    15578.0
# 378    15578.0
# 379    15578.0
# 380    15578.0
# 381    15578.0
# 382    15578.0
# 383    15578.0
# 384    15578.0
# 385    15578.0
# 386     8425.0
# 387     8425.0
# 388    15578.0
# 389     8425.0
# 390    15578.0
# 391    15578.0
# 392    15578.0
# 393    15578.0
# 394    15578.0
# 395    15578.0
# ...

# %%
df['horsepower']=df['horsepower'].fillna(df.groupby(['cylinders'])['horsepower'].transform('mean'))

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.132947  2970.424623
# std      7.815984    1.701004    104.269838   38.310886   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   76.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   92.000000  2803.500000
# 75%     29.000000    8.000000    262.000000  125.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
df['horsepower'].mean()
# Out:
# 104.13294738510618

# %%
import seaborn as sns
#sns.pairplot(df.loc[:,df.dtypes=='float64'])
column_need=['mpg','cylinders','weight','displacement','horsepower']
sns.pairplot(df[column_need])

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0  130.000000    3504          12.0    70
# 1    15.0          8         350.0  165.000000    3693          11.5    70
# 2    18.0          8         318.0  150.000000    3436          11.0    70
# 3    16.0          8         304.0  150.000000    3433          12.0    70
# 4    17.0          8         302.0  140.000000    3449          10.5    70
# 5    15.0          8         429.0  198.000000    4341          10.0    70
# 6    14.0          8         454.0  220.000000    4354           9.0    70
# 7    14.0          8         440.0  215.000000    4312           8.5    70
# 8    14.0          8         455.0  225.000000    4425          10.0    70
# 9    15.0          8         390.0  190.000000    3850           8.5    70
# 10   15.0          8         383.0  170.000000    3563          10.0    70
# ...

# %%
df[df['horsepower'].isnull()]
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name]
# Index: []

# %%
df.groupby(['cylinders','origin'])['horsepower'].transform('mean').unique()
# Out:
# array([158.30097087,  75.57971014,  99.69602735,  78.31052086,
#         80.84505863,  99.25      , 115.83333333, 113.5       ,
#         82.33333333])

# %%
df.groupby(['cylinders','origin'])['horsepower'].transform('mean')
# Out:
# 0      158.300971
# 1      158.300971
# 2      158.300971
# 3      158.300971
# 4      158.300971
# 5      158.300971
# 6      158.300971
# 7      158.300971
# 8      158.300971
# 9      158.300971
# 10     158.300971
# 11     158.300971
# 12     158.300971
# 13     158.300971
# 14      75.579710
# 15      99.696027
# 16      99.696027
# 17      99.696027
# 18      75.579710
# 19      78.310521
# 20      78.310521
# 21      78.310521
# 22      78.310521
# 23      78.310521
# 24      99.696027
# 25     158.300971
# 26     158.300971
# 27     158.300971
# 28     158.300971
# 29      75.579710
#           ...
# 368     80.845059
# 369     80.845059
# 370     80.845059
# 371     80.845059
# 372     80.845059
# 373     80.845059
# 374     80.845059
# 375     78.310521
# 376     75.579710
# 377     75.579710
# 378     80.845059
# 379     80.845059
# 380     75.579710
# 381     75.579710
# 382     75.579710
# 383     75.579710
# 384     75.579710
# 385     75.579710
# 386     99.696027
# ...

# %%
df.pivot_table(index=['cylinders'],values=['horsepower'],aggfunc=np.mean)
# Out:
#            horsepower
# cylinders
# 3           99.250000
# 4           78.281407
# 5           82.333333
# 6          101.506024
# 8          158.300971

# %%
for i in df.columns:
    #print(i)
    print(df[df[i].isnull()])
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name]
# Index: []
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name]
# Index: []
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name]
# Index: []
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name]
# Index: []
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name]
# Index: []
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name]
# Index: []
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name]
# Index: []
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name]
# ...

# %%
sns.pairplot(df)

# %%
column_need
# Out:
# ['mpg', 'cylinders', 'weight', 'displacement', 'horsepower']

# %%
sns.pairplot(df[column_need])

# %%
sns.set(color_codes=True)

# %%
g=sns.pairplot(df[column_need],hue="cylinders")
g.savefig("output.png")
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Owner\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Owner\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\Owner\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
g.savefig("output.png")

# %%
sns.regplot(x="horsepower",y="mpg",data=df)
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(df[column_need],kind="reg")
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.boxplot(df['mpg'],orient='v')

# %%
sns.violinplot(y="mpg",data=df)
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.violinplot(x="cylinders",y="mpg",data=df)
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
corr=df[column_need].corr()
sns.heatmap(corr, xticklabels=corr.columns,yticklabels=corr.columns, cmap=sns.diverging_palette(150,10,as_cmap=True))

# %% [markdown]
# # Merge or Join
# ** We will join 2 data frames

# %%
result=pd.DataFrame(df.groupby(['cylinders'])['horsepower'].aggregate('mean'))

# %%
result.head()
# Out:
#            horsepower
# cylinders
# 3           99.250000
# 4           78.281407
# 5           82.333333
# 6          101.506024
# 8          158.300971

# %%
df[column_need]
# Out:
#       mpg  cylinders  weight  displacement  horsepower
# 0    18.0          8    3504         307.0  130.000000
# 1    15.0          8    3693         350.0  165.000000
# 2    18.0          8    3436         318.0  150.000000
# 3    16.0          8    3433         304.0  150.000000
# 4    17.0          8    3449         302.0  140.000000
# 5    15.0          8    4341         429.0  198.000000
# 6    14.0          8    4354         454.0  220.000000
# 7    14.0          8    4312         440.0  215.000000
# 8    14.0          8    4425         455.0  225.000000
# 9    15.0          8    3850         390.0  190.000000
# 10   15.0          8    3563         383.0  170.000000
# 11   14.0          8    3609         340.0  160.000000
# 12   15.0          8    3761         400.0  150.000000
# 13   14.0          8    3086         455.0  225.000000
# 14   24.0          4    2372         113.0   95.000000
# 15   22.0          6    2833         198.0   95.000000
# ...

# %%
new_df=pd.merge(df[column_need],result,how='left',left_on=['cylinders'],right_on=['cylinders'])

# %%
new_df.head()
# Out:
#     mpg  cylinders  weight  displacement  horsepower_x  horsepower_y
# 0  18.0          8    3504         307.0         130.0    158.300971
# 1  15.0          8    3693         350.0         165.0    158.300971
# 2  18.0          8    3436         318.0         150.0    158.300971
# 3  16.0          8    3433         304.0         150.0    158.300971
# 4  17.0          8    3449         302.0         140.0    158.300971
